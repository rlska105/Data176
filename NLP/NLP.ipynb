# %% [markdown]
# # NLP
#
# - 개요<br>
# NLP란 컴퓨터가 자연어를 분석하고 처리하는 것을 말함<br>
# 자연어 처리 분야는 1.음성 인식 2.자연어 이해 3.자연어 생성 등이 있음<br><br>
#
# 주의사항 : NLP방식에 따라 중요한 단어를 놓칠 수도 있고, 불필요한 단어를 포함시킬 수도 있음 (not a one-size-fits-all approach)
#
# - 활용분야 추가?????

# %% [markdown]
# # NLP preprocessing
# NLP를 하기 위해서는 다양한 사전 처리가 필요(토큰화, 정규화 등). NLP에서 텍스트 자체를 feature로 사용할 수 없기 때문에 토큰화를 해서 단어를 하나하나 쪼개는 작업이 필요 e.g. 부정적인 문장을 감성 분석했을 때 불용어를 처리하기 전에는 negative와 positive의 중간에 있었지만 불용어를 처리하고 분석을 했을 때는 negative 쪽으로 기움
#
# ## Preprocessing 크게 3가지 메인 스텝
# - Tokenization<br>
# 토큰화는 문장을 분리하여 작은 조각(또는 토큰)으로 만드는 것을 뜻함<br>
# 하나의 절은 문장으로, 문장은 단어로 토큰화될 수 있음<br><br>
#
# - Text normalization<br>
# 텍스트 정규화란, 텍스트를 표준 형식으로 변환하는 것을 말하며, 최근에 생성되는 텍스트 데이터의 특징은 줄임말이나 유행어가 많이 포함되므로 정규화는 굉장히 중요한 과정임(대표적으로는 sns 코멘트가 있음)<br>
# 정규화란 표현 방법이 다른 단어들을 통합시켜서 같은 단어로 만드는데 가령, USA와 US는 같은 의미를 가지므로, 하나의 단어로 정규화될 수 있음

# %%
from IPython.display import Image
Image(filename='/Users/kimginam/Data176/NLP/normalization.png', width = 500, height = 200)

# %% [markdown]
# - Noise removal<br>
# 노이즈 제거란, 분석에 불필요한 단어(불용어)나 문자(띄어쓰기 등)를 제거하는 작업을 의미함<br>

# %% [markdown]
# ## Preprocessing 구체적인 10가지 스텝
# 1. HTML tags 제거
# 2. 띄어쓰기 제거
# 3. accented characters를 ASCII characters로 전환 e.g. latté와 café를 latte와 cafe로 전환
# 4. 축약형 확장 e.g. don’t이나 can’t을 do not이나 can not과 같은 기본형으로 확장
# 5. 특수문자 제거
# 6. 소문자로 변환
# 7. 숫자(문자형) 숫자형으로 변환 e.g. 하나,일 → 1
# 8. 불필요한 숫자 제거
# 9. 불용어 제거
# 10. Lemmatization(표제화)
#
# *표제화란, 문장 속에서 다양한 형태로 활용된 단어의 표제어(lemma)를 찾는 일을 뜻함<br>
# *표제어(Lemma)란 사전에서 단어의 뜻을 찾을 때 쓰는 기본형이라고 생각하면 된다. am, are, is는 서로 다른 스펠링이지만 그 뿌리 단어는 be라고 볼 수 있습니다. 이때, 이 단어들의 표제어는 be라고 합니다.
