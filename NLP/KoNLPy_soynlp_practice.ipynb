# %%
import numpy as np
import pandas as pd

import datetime as dt

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%time
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor
# Out:
# CPU times: user 240 ms, sys: 114 ms, total: 354 ms
# Wall time: 3.2 s

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint
kkma = Kkma()

# %%
f = open("/Users/kimginam/Data176/NLP/교통약자민원_워드클라우드.txt", "r")
f = f.read()

# %%
type(f)
# Out:
# str

# %%
f
# Out:
# '그, 버스에 씌워놓은 덮개있죠? 하얀색, 노란색, 빨간색으로, 노약자석과 임산부석을 표시해둔 덮개. 근데 노란색으로 표시해둔 게 ‘경로석’이라고 되어있더라고요.\n서울 지하철도, 어딜가든 요즘은 ‘노약자석’으로 표시해둡니다. 근데 왜 아직도 제주도 버스만은(제주도만은??) ‘경로석’일까요?\n\n어제 6시 15분쯤, 퇴근하고 중앙로터리에서 352번 버스를 탔습니다. 퇴근시간이었고 사람들이 많이 다니는 노선이라 버스 안엔 비어있는 자리가 거의 없었죠. 저는 노란색으로 표시된 자리에 앉았는데, 바로 다음 정류장인 동문로타리에서 탑승하여 제 옆자리에 앉으신 할아버지 한분께서 저를 툭툭 치시고 앞자리에 쓰여진 글씨를 가리키며 “이거 안보여??”하셨습니다. 너는 젊으니 이 노란 두줄, 네 자리는 비워둬야 한다는 뜻이었죠.\n\n매일같이 버스로 출퇴근을 하면서, 가방으로 밀치거나, 일어나라고 눈치주는 할머니 할아버지는 많이 봤습니다만 대놓고 ‘이거 네 개 좌석은 노인들 좌석이다’라고 말하는 분은 처음이엇습니다.\n\n그리고 저는 4급의 경증장애인인데요. 교통약자콜은 탈수가 없습니다. 중증장애인 친구와 타고 가다 중간에 내리려 해도 저는 비장애인으로 취급되어 안됩니다. 만약 ‘노약자석’이라고만 되어있었으면 저는 그 할아버지께, 제 복지카드를 내밀며 “저도 노약자입니다.”할 수 있었겠지만 ‘경로석’이라는 것에는 맞받아칠 말이 생각나지 않더군요.\n\n물론 우리나라는 동방예의지국이고, 어른이 오면 일어나서 비켜드려서 젊은사람이 희생하는게 맞다고 생각합니다 저도. 그래서 짐을 많이 드신 할머니나 나이가 많이 드신 할아버지가 타시면 양보도 많이 하고요. 근데 젊은 사람중에도, 저처럼 티나지 않는 장애를 가졌거나 양보하기 힘든 사정을 가진 사람들이 있을수도 있거든요. 할아버지 할머니들이 그렇다고, 임산부석 두석을 꼭 비워놓으시는건 아니잖아요.\n\n\n그리고 또 하나는, 줄서기에 관한 내용입니다.\n버스정류장에서 버스를 기다리다 보면 곧 내가 탈 버스가 뜨죠. 그래서 앞에서 버스를 기다리면 어느새 옆에 있는 사람이 새치기를 합니다.\n그럼 앞에서 한동안 버스를 기다렸던 전 기분이 확 상하거든요.\n\n버스를 기다리다 보면, 옆에 인도 끝에 서서 누가 처음인지도 모르고 버스가 오면 우르르 양 옆에서 나가고. 특히 아줌마들은 다리나 가방부터 나가고 밀고 하다보면 저는 한쪽 눈이 실명이라 조심하다보면 또 제 순서도 놓치고 다칠까 걱정도 되거든요.\n\n그 기계(??) 뭐라고 하는지 모르겠는데, 버스정류장에 있는 기계(가끔 공익광고도 나오고 하던데)는 자기가 탈 버스 기다리느라 어차피 보게 되니까 거기에라도 줄서기에 대한 내용을 좀 넣어주셨으면 합니다. 버스 안에 있는(다음 정류장 안내해주는) 거에도요. 못하면 자막으로라도 띄워주세요. 물론 1번, 2번 번호표 뽑고 기다릴 순 없겠지만 자주 보여주는 효과를 나타내면 그래도 전보다는 의식이 변할수 있다고 생각합니다. 요즘은 코로나 때문에 그 내용을 계속 내보내셔야겠지만, 정말 생각할 필요 있는 내용이라고 생각되네요. 매일매일 버스로 출퇴근하는 사람의 입장으로서 상당히 불쾌할 때가 많아요\n중앙로 동문로타리 이쪽은 또 장보러 나온 아줌마들이 많아 엄마뻘 분들에게 뭐라 하지도 못하고요..\n그럼 수고하세요.\n최근 오일장 입구 사거리에 도로 확장하면서 도보통행시 건널목 신호체계가 짧아 학생들과 시민들이 불편을 격고있습니다.\n이전엔 신호가 짧지 않았던것 같은데, 도로 확장하면서 신호체계는 반영이 안된것 같습니다. 건널목인 만큼은 뛰지않고 꼬리잡기 안해도 건널 수 있는 시간을 확보해주세요.\n\n대략 건널목 신호가 12초 조금 넘었던것 같은데, 중학생들임에도 불구하고 마지막엔 뛰어야 인도에 도착하는것을 관찰했습니다. 교통약자인 어르신들이나 어린 초등생들이나 더 위험할것 같은데 먼저 신호체계를 선처해주시면 감사하겠습니다.\n장애인 당사자로서 위 영화관은 장애인이 주차하기가 상당히 불편한 극장으로 이용을 하지 않은 사람입니다.\n불가피한 경우 영화 관람을 하러 가는데\n\n위 극장의 가장 큰 문제점은 붙임 사진과 같이 우측에 주차장 용도로 활용하고 있는 건축물에 대하여 장애인 노인 임산부 등의 편의 증진 보장에 관한 법률 제7조의 규정에 의한 편의시설을 설치를 하지 않고 건축물을 허가 및 사용승인을 한 이유(허가가 난 상황이면)와\n\n장애인 편의시설을 설치적용 배제시설이면 그 근거를 알려 주시기 바랍니다. 향후 제도상 보완 계획은?\n\n아울러 위 시설물은 주차장 용도가 아닌 건축물로 건축 허가를 하였음에도 경차 우선 주차 공간은 설정하고 있는 상황임을 감안하여 주목적은 주차장 용도로 활용하고 있는 부설 건축물이라 볼 수 있음\n\n제주시 관련 부서에 민원사항을 이야기 하였음에도 불구 관련 부서에서는 전혀 이야기가 없음\n\n* 일반적인 다중 이용 시설에 따른 주차장 용도로 활용하는 건축물에 대해서는 상식적으로 교통약자에 대한 편의 시설 설치가 우선이라는 생각이 듬\n제주시 중앙사거리를 이용하다보면 길을 건너려고 하면 중앙지하상가 지하를 이용해야하는데 노약자 및 교통약자들의 편의를 위해서 사거리에 횡단보도를 설치하는게 보행권 보호차원에서 필요하다고 생각되는데요.최근 자치경찰단과 제주시청 건설과 담당자와 통화시에 자치경찰단에서는 2007년도에 심의를거쳐 제주시로 설치권고 했는데 아직까지 근10년동안 설치가 미뤄지고 있다고하고, 또한 제주시청 건설과 담당은 2014년도에 이관되어 이직까지도 소관부처끼리 협의중이라는 답변을 들었는데 언제면 협의가 마무리되어 설치가 될것이며, 또한 설치하려면 우선 지하상가 상인들하고 우선 협의를해야 된다는데, 이건 말도안되는 소리이며, 횡단보도같은 공공시설물이 일부상인들이 반대하면 설치도 못한다는게 시민입장에서는 도저히 납득이 안되어 글을 게시합니다,빠른 시일내에 답변부탁드리며 답변이 없을시는 직원들의 근무태만으로 간주하겠읍니다.\n\n수고 많으십니다. 본인은 제주를 자주 방문하며, 제주 버스를 많이 이용합니다.\n제주는 전국적으로 버스 체계가 잘 되어 있어, 이용이 편리합니다.\n그런데, 이용하면서 몇가지 개선이 되면 더욱 좋을 것 같아 제안하오니, 본 제안이 관계부서에 전달되어 적극 검토해 주시기 바랍니다.\n1.제주 버스의 불친절에 대한 제안\n버스를 이용하면서 자주 느끼는 것이 기사들의 불친절입니다. 관광객과 젊은 사람들한테는 대체적으로 친절한 편입니다. 그러나 지역민, 특히 노인들한테는 상당히 불친절하고, 때로는 무시하거나 화내고, 신경질을 부립니다. 본인은 삼자로서도 지나치다는 마음에서 이런 제안을 합니다.\n노인들이 지금의 교통수단에 미숙하고, 행동이 늦을 수 밖에 없는 것인데, 그런 것은 충분히 감안한 운행시스템과 기사들의 자세가 필요하지 않을까요?. 노인들이 수십년 동안 몸에 익은 생활 습관과 노쇠한 탓일 것입니다. 그러나 그런 노인들이 지금의 제주를 지켜왔다고 생각합니다.\n기사들이 젊어서 그런지 모르겠지만, 그들도 늙을 것이고, 기사들의 부모님도 늙었을 것입니다. 그런 노인들이 있기에 지금의 제주가 있고, 지금의 제주가 있기에 기사들이 그런 좋은 직장을 가질 수 있다는 것에 감사의 마음이 앞서야 할 것 아닌가 싶습니다.\n두 번째는 관광객에 대한 불친절입니다. 관광객은 제주에 머무는 동안, 제주의 모든 것을 최대한 경험하고, 보고 가려합니다. 그래서, 가까운 길로만 다니는 것이 아니고, 조금 멀고 시간이 더 걸려도 중산간 버스나 일주버스를 이용하여 제주의 아름다운 모습을 눈에 담으려고 합니다. 예를 들면, 일주버스를 타고 여행하다, 중간에 중산간 버스로 환승을 하거나, 처음부터 중산간 버스로 이동합니다. 그 때 기사들은 환승 승차를 거부하고, 다시 버스비를 부담하라고 강요합니다. 또, 중산간버스로 종점까지 가려하면 노골적으로 불편한 심기를 보입니다.\n주민이나 관광객이 이럴 때마다 기사들과 다투거나 입씨름을 하기 싫어, 혹 기사의 심경이 불편하면 안전운행이 걱정되어 참는 것이 예사입니다.\n제안합니다. 모든 기사님들에게 소명의식과 친절 교육을 강화하고, 친절한 기사는 수당을 더 지급하고, 불친절한 기사는 수당을 덜 지급하는 방식 같은 것을 말입니다. 지금은 차량  ...
