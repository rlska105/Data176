# %%
import numpy as np
import pandas as pd

import datetime as dt

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%time
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor
# Out:
# CPU times: user 17 µs, sys: 77 µs, total: 94 µs
# Wall time: 112 µs

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint
kkma = Kkma()

# %%
f = open("/Users/kimginam/Data176/NLP/교통약자민원_워드클라우드.txt", "r")
f = f.read()

# %%
type(f)
# Out:
# str

# %%
f
# Out:
# '그, 버스에 씌워놓은 덮개있죠? 하얀색, 노란색, 빨간색으로, 노약자석과 임산부석을 표시해둔 덮개. 근데 노란색으로 표시해둔 게 ‘경로석’이라고 되어있더라고요.\n서울 지하철도, 어딜가든 요즘은 ‘노약자석’으로 표시해둡니다. 근데 왜 아직도 제주도 버스만은(제주도만은??) ‘경로석’일까요?\n\n어제 6시 15분쯤, 퇴근하고 중앙로터리에서 352번 버스를 탔습니다. 퇴근시간이었고 사람들이 많이 다니는 노선이라 버스 안엔 비어있는 자리가 거의 없었죠. 저는 노란색으로 표시된 자리에 앉았는데, 바로 다음 정류장인 동문로타리에서 탑승하여 제 옆자리에 앉으신 할아버지 한분께서 저를 툭툭 치시고 앞자리에 쓰여진 글씨를 가리키며 “이거 안보여??”하셨습니다. 너는 젊으니 이 노란 두줄, 네 자리는 비워둬야 한다는 뜻이었죠.\n\n매일같이 버스로 출퇴근을 하면서, 가방으로 밀치거나, 일어나라고 눈치주는 할머니 할아버지는 많이 봤습니다만 대놓고 ‘이거 네 개 좌석은 노인들 좌석이다’라고 말하는 분은 처음이엇습니다.\n\n그리고 저는 4급의 경증장애인인데요. 교통약자콜은 탈수가 없습니다. 중증장애인 친구와 타고 가다 중간에 내리려 해도 저는 비장애인으로 취급되어 안됩니다. 만약 ‘노약자석’이라고만 되어있었으면 저는 그 할아버지께, 제 복지카드를 내밀며 “저도 노약자입니다.”할 수 있었겠지만 ‘경로석’이라는 것에는 맞받아칠 말이 생각나지 않더군요.\n\n물론 우리나라는 동방예의지국이고, 어른이 오면 일어나서 비켜드려서 젊은사람이 희생하는게 맞다고 생각합니다 저도. 그래서 짐을 많이 드신 할머니나 나이가 많이 드신 할아버지가 타시면 양보도 많이 하고요. 근데 젊은 사람중에도, 저처럼 티나지 않는 장애를 가졌거나 양보하기 힘든 사정을 가진 사람들이 있을수도 있거든요. 할아버지 할머니들이 그렇다고, 임산부석 두석을 꼭 비워놓으시는건 아니잖아요.\n\n\n그리고 또 하나는, 줄서기에 관한 내용입니다.\n버스정류장에서 버스를 기다리다 보면 곧 내가 탈 버스가 뜨죠. 그래서 앞에서 
# ...

# %% [markdown]
# ### Kkma

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# 꼬꼬마의 단점은 긴 문장이나 띄어쓰기가 재대로 되어있지 않으면 잘 작동하지 않는다는 점입니다.
print(kkma.morphs(u'공부를 하면할수록 모르는게 많다는 것을 알게 됩니다.'))
# Out:
# ['공부', '를', '하', '면', '하', 'ㄹ수록', '모르', '는', '것', '이', '많', '다는', '것', '을', '알', '게', '되', 'ㅂ니다', '.']

# %%
d = kkma.nouns(f)

# %%
pos = kkma.pos(f)

# %%
pos
# Out:
# [('그', 'NP'),
#  (',', 'SP'),
#  ('버스', 'NNG'),
#  ('에', 'JKM'),
#  ('씌우', 'VV'),
#  ('어', 'ECS'),
#  ('놓', 'VXV'),
#  ('은', 'ETD'),
#  ('덮개', 'NNG'),
#  ('있', 'VV'),
#  ('죠', 'EFN'),
#  ('?', 'SF'),
#  ('하얀색', 'NNG'),
#  (',', 'SP'),
#  ('노란색', 'NNG'),
#  (',', 'SP'),
#  ('빨간색', 'NNG'),
#  ('으로', 'JKM'),
#  (',', 'SP'),
#  ('노약자', 'NNG'),
#  ('석', 'NNG'),
#  ('과', 'JKM'),
#  ('임산', 'NNG'),
#  ('부석', 'NNG'),
#  ('을', 'JKO'),
#  ('표시', 'NNG'),
#  ('하', 'XSV'),
#  ('어', 'ECS'),
#  ('두', 'VXV'),
#  ('ㄴ', 'ETD'),
#  ('덮개', 'NNG'),
#  ('.', 'SF'),
#  ('근데', 'MAG'),
#  ('노란색', 'NNG'),
#  ('으로', 'JKM'),
#  ('표시', 'NNG'),
#  ('하', 'XSV'),
#  ('어', 'ECS'),
#  ('두', 'VXV'),
#  ('ㄴ', 'ETD'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('‘', 'SS'),
#  ('경로', 'NNG'),
#  ('석', 'NNG'),
#  ('’', 'SS'),
#  ('이', 'VCP'),
#  ('라고', 'ECD'),
#  ('되', 'VV'),
#  ('어', 'ECD'),
#  ('있', 'VXV'),
#  ('더', 'EPT'),
#  ('라고요', 'EFN'),
#  ('.', 'SF'),
#  ('서울', 'NNG'),
#  ('지하철', 'NNG'),
#  ('도', 'JX'),
#  (',', 'SP'),
# ...

# %% [markdown]
# ### 한나눔

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()
print(hannanum.analyze(u'롯데마트의 흑마늘 양념 치킨이 논란이 되고 있다.'))
# Out:
# [[[('롯데마트', 'ncn'), ('의', 'jcm')], [('롯데마트의', 'ncn')], [('롯데마트', 'nqq'), ('의', 'jcm')], [('롯데마트의', 'nqq')]], [[('흑마늘', 'ncn')], [('흑마늘', 'nqq')]], [[('양념', 'ncn')]], [[('치킨', 'ncn'), ('이', 'jcc')], [('치킨', 'ncn'), ('이', 'jcs')], [('치킨', 'ncn'), ('이', 'ncn')]], [[('논란', 'ncpa'), ('이', 'jcc')], [('논란', 'ncpa'), ('이', 'jcs')], [('논란', 'ncpa'), ('이', 'ncn')]], [[('되', 'nbu'), ('고', 'jcj')], [('되', 'nbu'), ('이', 'jp'), ('고', 'ecc')], [('되', 'nbu'), ('이', 'jp'), ('고', 'ecs')], [('되', 'nbu'), ('이', 'jp'), ('고', 'ecx')], [('되', 'paa'), ('고', 'ecc')], [('되', 'paa'), ('고', 'ecs')], [('되', 'paa'), ('고', 'ecx')], [('되', 'pvg'), ('고', 'ecc')], [('되', 'pvg'), ('고', 'ecs')], [('되', 'pvg'), ('고', 'ecx')], [('되', 'px'), ('고', 'ecc')], [('되', 'px'), ('고', 'ecs')], [('되', 'px'), ('고', 'ecx')]], [[('있', 'paa'), ('다', 'ef')], [('있', 'px'), ('다', 'ef')]], [[('.', 'sf')], [('.', 'sy')]]]

# %%
print(hannanum.morphs(u'롯데마트의 흑마늘 양념 치킨이 논란이 되고 있다.'))
# Out:
# ['롯데마트', '의', '흑마늘', '양념', '치킨', '이', '논란', '이', '되', '고', '있', '다', '.']

# %% [markdown]
# ### Twitter

# %%
from konlpy.tag import Twitter

# %%
twitter = Twitter()
twetter = twitter.nouns(f)

# %%
twetter
# Out:
# ['그',
#  '버스',
#  '덮개',
#  '하얀색',
#  '노란색',
#  '빨간색',
#  '노약',
#  '자석',
#  '임산부',
#  '석',
#  '표시',
#  '덮개',
#  '노란색',
#  '표시',
#  '게',
#  '경로',
#  '석',
#  '서울',
#  '지하철도',
#  '가든',
#  '요즘',
#  '노약',
#  '자석',
#  '표시',
#  '왜',
#  '제주도',
#  '버스',
#  '제주도',
#  '경로',
#  '석',
#  '요',
#  '어제',
#  '퇴근',
#  '중앙',
#  '로터리',
#  '번',
#  '버스',
#  '퇴근',
#  '시간',
#  '사람',
#  '노선',
#  '버스',
#  '안',
#  '자리',
#  '거의',
#  '저',
#  '노란색',
#  '표시',
#  '자리',
#  '바로',
#  '다음',
#  '정류장',
#  '로타리',
#  '탑승',
#  '제',
#  '옆',
#  '할아버지',
#  '분',
#  '저',
#  '툭툭',
#  '앞',
#  '글씨',
#  '거',
#  '안보',
#  '너',
#  '이',
#  '줄',
#  '네',
#  '뜻',
#  '매일',
#  '버스',
#  '출퇴근',
#  '가방',
#  '눈치',
#  '할머니',
#  '할아버지',
#  '거',
#  '네',
#  '개',
#  '좌석',
#  '노',
#  '좌석',
#  '말',
#  '분',
#  '처음',
#  '엇습',
#  '니',
#  '저',
#  '급',
#  '증장',
#  '애인',
#  '요',
#  '교통',
#  '약자',
#  '콜',
#  '탈수',
#  '중',
#  '증장',
#  '애인',
#  '친구',
#  '타고',
#  '중간',
#  '해도',
#  '저',
#  '비장',
#  '애인',
#  '취급',
#  '만약',
#  '노약',
#  '자석',
#  '저',
#  '그',
# ...

# %% [markdown]
# ### Counter words

# %%
from collections import Counter
dd = Counter(twetter)

# %%
dd
# Out:
# Counter({'그': 8,
#          '버스': 49,
#          '덮개': 2,
#          '하얀색': 1,
#          '노란색': 3,
#          '빨간색': 1,
#          '노약': 5,
#          '자석': 3,
#          '임산부': 3,
#          '석': 5,
#          '표시': 8,
#          '게': 1,
#          '경로': 3,
#          '서울': 1,
#          '지하철도': 1,
#          '가든': 1,
#          '요즘': 2,
#          '왜': 1,
#          '제주도': 2,
#          '요': 5,
#          '어제': 1,
#          '퇴근': 2,
#          '중앙': 4,
#          '로터리': 1,
#          '번': 9,
#          '시간': 5,
#          '사람': 12,
#          '노선': 1,
#          '안': 4,
#          '자리': 3,
#          '거의': 2,
#          '저': 11,
#          '바로': 1,
#          '다음': 2,
#          '정류장': 9,
#          '로타리': 2,
#          '탑승': 1,
#          '제': 4,
#          '옆': 4,
#          '할아버지': 5,
#          '분': 5,
#          '툭툭': 1,
#          '앞': 3,
#          '글씨': 1,
#          '거': 3,
#          '안보': 1,
#          '너': 1,
#          '이': 1,
#          '줄': 3,
#          '네': 2,
# ...

# %%
vocab_sorted = sorted(dd.items(), key = lambda x:x[1], reverse = True)
print(vocab_sorted)
# Out:
# [('버스', 49), ('제주', 22), ('것', 18), ('이용', 15), ('기사', 13), ('사람', 12), ('저', 11), ('설치', 10), ('환승', 10), ('번', 9), ('정류장', 9), ('그', 8), ('표시', 8), ('수', 7), ('생각', 7), ('때', 7), ('말', 6), ('노인', 6), ('시설', 6), ('지금', 6), ('노약', 5), ('석', 5), ('요', 5), ('시간', 5), ('할아버지', 5), ('분', 5), ('교통', 5), ('약자', 5), ('또', 5), ('신호', 5), ('경우', 5), ('건축물', 5), ('편의', 5), ('제안', 5), ('불친절', 5), ('중앙', 4), ('안', 4), ('제', 4), ('옆', 4), ('내용', 4), ('대한', 4), ('자주', 4), ('체계', 4), ('장애인', 4), ('주차장', 4), ('용도', 4), ('활용', 4), ('우선', 4), ('관광객', 4), ('중산', 4), ('출구', 4), ('배차', 4), ('간격', 4), ('출발', 4), ('노란색', 3), ('자석', 3), ('임산부', 3), ('경로', 3), ('자리', 3), ('앞', 3), ('거', 3), ('줄', 3), ('할머니', 3), ('개', 3), ('처음', 3), ('애인', 3), ('타고', 3), ('관', 3), ('전', 3), ('번호', 3), ('사거리', 3), ('건널목', 3), ('더', 3), ('위', 3), ('허가', 3), ('시기', 3), ('제도', 3), ('감안', 3), ('제주시', 3), ('부서', 3), ('길', 3), ('협의', 3), ('답변', 3), ('전국', 3), ('개선', 3), ('검토', 3), ('지역', 3), ('운행', 3), ('시스템', 3), ('친절', 3), ('확인',
# ...
